# %%
import pandas as pd

# %%
data = {'Fee': [22000, 25000], 'Duration': [3, 4]}
df = pd.DataFrame(data)
transposed_fee = df[['Fee']].transpose()
print(df)
# Out:
#      Fee  Duration
# 0  22000         3
# 1  25000         4

# %%
print(transposed_fee)
# Out:
#          0      1
# Fee  22000  25000

# %%
montenegroRegions = pd.DataFrame([
    [ 'Cetinje', "Central" ],
    [ 'Danilovgrad', "Central" ],
    [ 'Niksic', "Central" ],
    [ 'Podgorica',"Central" ],
    [ 'Tuzi', "Central" ],
    [ 'Zeta', "Central" ],
    [ 'Bar', "Costal" ] ,
    [ 'Budva', "Costal" ] ,
    [ 'Herceg Novi', "Costal" ] ,
    [ 'Kotor', "Costal" ] ,
    [ 'Tivat', "Costal" ] ,
    [ 'Ulcinj', "Costal" ] ,
    [ 'Andrijevica', "Nothern" ] ,
    [ 'Berane', "Nothern" ] ,
    [ 'Bijelo Polje', "Nothern" ] ,
    [  'Kolasin', "Nothern" ] ,
    [ 'Mojkovac', "Nothern" ] ,
    [ 'Plav', "Nothern" ] ,
    [ 'Pljevlja', "Nothern" ] ,
    [ 'Pluzine', "Nothern" ] ,
    [ 'Rozaje', "Nothern" ] ,
    [ 'Savnik', "Nothern" ] ,
    [ 'Zabljak', "Nothern" ] ,
    [ 'Gusinje', "Nothern" ] ,
    [ 'Petnjica', "Nothern" ] 
])
montenegroRegions = montenegroRegions.set_axis(["Municipality", "Region"], axis=1)
montenegroRegions
# Out:
#     Municipality   Region
# 0        Cetinje  Central
# 1    Danilovgrad  Central
# 2         Niksic  Central
# 3      Podgorica  Central
# 4           Tuzi  Central
# 5           Zeta  Central
# 6            Bar   Costal
# 7          Budva   Costal
# 8    Herceg Novi   Costal
# 9          Kotor   Costal
# 10         Tivat   Costal
# 11        Ulcinj   Costal
# 12   Andrijevica  Nothern
# 13        Berane  Nothern
# 14  Bijelo Polje  Nothern
# 15       Kolasin  Nothern
# 16      Mojkovac  Nothern
# 17          Plav  Nothern
# 18      Pljevlja  Nothern
# 19       Pluzine  Nothern
# 20        Rozaje  Nothern
# 21        Savnik  Nothern
# 22       Zabljak  Nothern
# 23       Gusinje  Nothern
# 24      Petnjica  Nothern
